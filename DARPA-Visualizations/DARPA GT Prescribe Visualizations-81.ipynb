# %%
import pandas as pd

# %%
Instance81 = pd.read_csv('Instance81.csv')

# %%
Instance81
# Out:
#       Timestep         VariableName     EntityIdx     Value         Metadata
# 0            1               Deaths  [Actor1-160]  0.000000      Actor alive
# 1            1           Casualties  [Actor1-160]  0.000000     Actor health
# 2            1             Evacuees  [Actor1-160]  0.000000   Actor location
# 3            1            Sheltered  [Actor1-160]  0.000000   Actor location
# 4            1            Wellbeing  [Actor1-160]  0.755000     Actor health
# 5            1               Wealth  [Actor1-160]  0.552500  Actor resources
# 6            1               Safety  [Region1-16]  1.000000      Region risk
# 7            1            Prosocial  [Actor1-160]  0.000000     Actor action
# 8            1           Antisocial  [Actor1-160]  0.000000     Actor action
# 9            1   Regional Wellbeing      Region01  0.666667     Actor health
# 10           1   Regional Wellbeing      Region02  0.675000     Actor health
# ...

# %%
type(Instance81)
# Out:
# pandas.core.frame.DataFrame

# %%
Instance81.Value.iloc[5766]
# Out:
# 1.0

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(Instance81.Value, 'o', Instance81.Timestep,)
plt.show()

# %%
plt.plot(Instance81.Timestep, Instance81.Value)
plt.show()

# %%
Instance81
# Out:
#       Timestep         VariableName     EntityIdx     Value         Metadata
# 0            1               Deaths  [Actor1-160]  0.000000      Actor alive
# 1            1           Casualties  [Actor1-160]  0.000000     Actor health
# 2            1             Evacuees  [Actor1-160]  0.000000   Actor location
# 3            1            Sheltered  [Actor1-160]  0.000000   Actor location
# 4            1            Wellbeing  [Actor1-160]  0.755000     Actor health
# 5            1               Wealth  [Actor1-160]  0.552500  Actor resources
# 6            1               Safety  [Region1-16]  1.000000      Region risk
# 7            1            Prosocial  [Actor1-160]  0.000000     Actor action
# 8            1           Antisocial  [Actor1-160]  0.000000     Actor action
# 9            1   Regional Wellbeing      Region01  0.666667     Actor health
# 10           1   Regional Wellbeing      Region02  0.675000     Actor health
# ...

# %%
casualties = Instance81[Instance81.VariableName == "Regional Casualties"]

# %%
casualties
# Out:
#       Timestep         VariableName EntityIdx  Value      Metadata
# 41           1  Regional Casualties  Region01    0.0  Actor health
# 42           1  Regional Casualties  Region02    0.0  Actor health
# 43           1  Regional Casualties  Region03    0.0  Actor health
# 44           1  Regional Casualties  Region04    0.0  Actor health
# 45           1  Regional Casualties  Region05    0.0  Actor health
# 46           1  Regional Casualties  Region06    0.0  Actor health
# 47           1  Regional Casualties  Region07    0.0  Actor health
# 48           1  Regional Casualties  Region08    0.0  Actor health
# 49           1  Regional Casualties  Region09    0.0  Actor health
# 50           1  Regional Casualties  Region10    0.0  Actor health
# 51           1  Regional Casualties  Region11    0.0  Actor health
# 52           1  Regional Casualties  Region12    0.0  Actor health
# 53           1  Regional Casualties  Region13    0.0  Actor health
# ...

# %%
Instance81[Instance81.VariableName == 'Regional Casualties']
# Out:
#       Timestep         VariableName EntityIdx  Value      Metadata
# 41           1  Regional Casualties  Region01    0.0  Actor health
# 42           1  Regional Casualties  Region02    0.0  Actor health
# 43           1  Regional Casualties  Region03    0.0  Actor health
# 44           1  Regional Casualties  Region04    0.0  Actor health
# 45           1  Regional Casualties  Region05    0.0  Actor health
# 46           1  Regional Casualties  Region06    0.0  Actor health
# 47           1  Regional Casualties  Region07    0.0  Actor health
# 48           1  Regional Casualties  Region08    0.0  Actor health
# 49           1  Regional Casualties  Region09    0.0  Actor health
# 50           1  Regional Casualties  Region10    0.0  Actor health
# 51           1  Regional Casualties  Region11    0.0  Actor health
# 52           1  Regional Casualties  Region12    0.0  Actor health
# 53           1  Regional Casualties  Region13    0.0  Actor health
# ...

# %%
deaths = Instance81[Instance81.VariableName == "Regional Deaths"]

# %%
deaths
# Out:
#       Timestep     VariableName EntityIdx  Value     Metadata
# 25           1  Regional Deaths  Region01    0.0  Actor alive
# 26           1  Regional Deaths  Region02    0.0  Actor alive
# 27           1  Regional Deaths  Region03    0.0  Actor alive
# 28           1  Regional Deaths  Region04    0.0  Actor alive
# 29           1  Regional Deaths  Region05    0.0  Actor alive
# 30           1  Regional Deaths  Region06    0.0  Actor alive
# 31           1  Regional Deaths  Region07    0.0  Actor alive
# 32           1  Regional Deaths  Region08    0.0  Actor alive
# 33           1  Regional Deaths  Region09    0.0  Actor alive
# 34           1  Regional Deaths  Region10    0.0  Actor alive
# 35           1  Regional Deaths  Region11    0.0  Actor alive
# 36           1  Regional Deaths  Region12    0.0  Actor alive
# 37           1  Regional Deaths  Region13    0.0  Actor alive
# 38           1  Regional Deaths  Region14    0.0  Actor alive
# ...

# %%
plt.plot(casualties.Timestep, casualties.Value)
plt.show()

# %%
plt.plot(casualties.Timestep, casualties.Value)
plt.plot(deaths.Timestep, deaths.Value)
plt.legend(['casualties', 'deaths'])
plt.xlabel('Days')
plt.ylabel('Persons')
plt.show()

# %%
plt.plot(casualties.Timestep, casualties.Value)
plt.plot(deaths.Timestep, deaths.Value)
plt.legend(['casualties', 'deaths'])
plt.xlabel('Timestep')
plt.ylabel('Persons')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
casualties.sort_index().cumsum().plot()

# %%
df1 = ["casualties.Timestep", "casualties.Value"]

# %%
plt.show(df1)

# %%
df1.cumsum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-f4cb74375e17> in <module>
# ----> 1 df1.cumsum()
#
# AttributeError: 'list' object has no attribute 'cumsum'

# %%
Instance81['cumulative_sum'] = casualties.cumsum()
plt.xticks(casualties.index, casualties.Timestep.values)
plt.xlim(0, 100)
plt.yticks(casualties.index, casualties.Value.values)
plt.ylim(0, 5000)
plt.plot(Instance81['cumulative_sum'])
plt.show()
